# %%
# !git clone --depth 1 https://github.com/spMohanty/PlantVillage-Dataset.git
# Out:
# Cloning into 'PlantVillage-Dataset'...
# remote: Enumerating objects: 163214, done.
# remote: Counting objects: 100% (163214/163214), done.
# remote: Compressing objects: 100% (163119/163119), done.
# remote: Total 163214 (delta 93), reused 163211 (delta 93), pack-reused 0 (from 0)
# Receiving objects: 100% (163214/163214), 2.00 GiB | 41.53 MiB/s, done.
# Resolving deltas: 100% (93/93), done.
# Updating files: 100% (182401/182401), done.

# %%
import os

dataset_path = "PlantVillage-Dataset/raw/color"
classes = os.listdir(dataset_path)
print(f"Total classes: {len(classes)}")
print(classes)
# Out:
# Total classes: 38
# ['Potato___Late_blight', 'Squash___Powdery_mildew', 'Corn_(maize)___healthy', 'Cherry_(including_sour)___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Strawberry___healthy', 'Soybean___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Tomato___Leaf_Mold', 'Strawberry___Leaf_scorch', 'Corn_(maize)___Common_rust_', 'Peach___Bacterial_spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Apple___Apple_scab', 'Corn_(maize)___Northern_Leaf_Blight', 'Pepper,_bell___healthy', 'Tomato___Septoria_leaf_spot', 'Blueberry___healthy', 'Apple___healthy', 'Pepper,_bell___Bacterial_spot', 'Apple___Cedar_apple_rust', 'Apple___Black_rot', 'Potato___Early_blight', 'Tomato___Early_blight', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Raspberry___healthy', 'Grape___Black_rot', 'Tomato___Late_blight', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Tomato___Bacterial_spot', 'Grape___healthy', 'Potato___healthy', 'Tomato___healthy', 'Grape___Esca_(Black_Measles)', 'Peach___healthy']

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
import os

# Enable CuDNN optimizations
torch.backends.cudnn.benchmark = True

# Define transforms (smaller image size: 128×128)
transform = transforms.Compose([
    transforms.Resize((227, 227)),  # Reduced image size
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset
dataset_path = "PlantVillage-Dataset/raw/color"  # Modify path in Kaggle
dataset = ImageFolder(root=dataset_path, transform=transform)

# Split dataset: 60% Train, 20% Validation, 20% Test
train_size = int(0.6 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# Use smaller batch size
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# Check dataset class labels
class_names = dataset.classes
print(f"Total classes: {len(class_names)}")
print(class_names)
# Out:
# Total classes: 38
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from tqdm import tqdm
from torch.utils.data import DataLoader

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load the pretrained AlexNet model
model = models.alexnet(weights=models.AlexNet_Weights.IMAGENET1K_V1)
num_ftrs = model.classifier[6].in_features  # Get input features of the last FC layer
num_classes = 38  # PlantVillage has 38 classes

# Replace the classifier
model.classifier[6] = nn.Linear(num_ftrs, num_classes)

# Freeze all layers except classifier
for param in model.parameters():
    param.requires_grad = False
for param in model.classifier[6].parameters():
    param.requires_grad = True

# Move model to device
model = model.to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier[6].parameters(), lr=0.0001)

# Mixed Precision Training
scaler = torch.amp.GradScaler()

# DataLoader (AlexNet expects 227x227 images)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# Training setup
num_epochs = 10
train_acc_history = []
val_acc_history = []
test_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    loop = tqdm(train_loader, leave=True, desc=f"Epoch {epoch+1}/{num_epochs}")
    for images, labels in loop:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda"):
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

        loop.set_postfix(loss=f"{running_loss / len(train_loader):.4f}", acc=f"{100 * correct / total:.2f}%")

# Save model
torch.save(model.state_dict(), "alexnet_trained.pth")
print("\n🚀 Model saved as alexnet_trained.pth")
# Out:
# Using device: cuda
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 199MB/s]
# Epoch 1/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.33it/s, acc=76.70%, loss=0.9467]
# Epoch 2/10: 100%|██████████| 1019/1019 [00:45<00:00, 22.16it/s, acc=88.29%, loss=0.4272]
# Epoch 3/10: 100%|██████████| 1019/1019 [00:45<00:00, 22.44it/s, acc=90.15%, loss=0.3418]
# Epoch 4/10: 100%|██████████| 1019/1019 [00:46<00:00, 22.05it/s, acc=90.98%, loss=0.3038]
# Epoch 5/10: 100%|██████████| 1019/1019 [00:45<00:00, 22.50it/s, acc=91.64%, loss=0.2721]
# Epoch 6/10: 100%|██████████| 1019/1019 [00:45<00:00, 22.19it/s, acc=92.24%, loss=0.2560]
# Epoch 7/10: 100%|██████████| 1019/1019 [00:45<00:00, 22.58it/s, acc=92.62%, loss=0.2413]
# Epoch 8/10: 100%|██████████| 1019/1019 [00:44<00:00, 22.74it/s, acc=92.67%, loss=0.2299]
# Epoch 9/10: 100%|██████████| 1019/1019 [00:45<00:00, 22.26it/s, acc=93.22%, loss=0.2192]
# Epoch 10/10: 100%|██████████| 1019/1019 [00:44<00:00, 22.70it/s, acc=93.29%, loss=0.2109]
# 🚀 Model saved as alexnet_trained.pth

# %%
import numpy as np
import torch

# Function to calculate per-class accuracy for different datasets
def calculate_per_class_accuracy(model, data_loaders, device, datasets=["Training", "Validation", "Test"]):
    for dataset_type, data_loader in zip(datasets, data_loaders):
        model.eval()
        class_correct = np.zeros(num_classes)
        class_total = np.zeros(num_classes)

        with torch.no_grad():
            for images, labels in data_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs, 1)

                for i in range(len(labels)):
                    label = labels[i].item()
                    class_correct[label] += (predicted[i] == label).item()
                    class_total[label] += 1

        # Print per-class accuracy for the current dataset
        print(f"\n📊 Final Per-Class {dataset_type} Accuracy:\n")
        for i in range(num_classes):
            accuracy = 100 * class_correct[i] / class_total[i] if class_total[i] > 0 else 0
            print(f"{class_names[i]}: {dataset_type} = {accuracy:.2f}%")


# ---------- Calculate Per-Class Accuracy for Training, Validation, and Test Data ----------
# List of data loaders for training, validation, and test datasets
data_loaders = [train_loader, val_loader, test_loader]

# List of dataset names
datasets = ["Training", "Validation", "Test"]

# Call the function for calculating accuracy
calculate_per_class_accuracy(model, data_loaders, device, datasets=datasets)
# Out:
# 📊 Final Per-Class Training Accuracy:
#
# Apple___Apple_scab: Training = 94.31%
# Apple___Black_rot: Training = 97.36%
# Apple___Cedar_apple_rust: Training = 98.81%
# Apple___healthy: Training = 94.89%
# Blueberry___healthy: Training = 99.89%
# Cherry_(including_sour)___Powdery_mildew: Training = 98.37%
# Cherry_(including_sour)___healthy: Training = 98.80%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Training = 92.76%
# Corn_(maize)___Common_rust_: Training = 100.00%
# Corn_(maize)___Northern_Leaf_Blight: Training = 98.32%
# Corn_(maize)___healthy: Training = 100.00%
# Grape___Black_rot: Training = 99.15%
# Grape___Esca_(Black_Measles): Training = 94.41%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Training = 99.85%
# Grape___healthy: Training = 99.61%
# Orange___Haunglongbing_(Citrus_greening): Training = 99.94%
# Peach___Bacterial_spot: Training = 98.54%
# Peach___healthy: Training = 99.13%
# Pepper,_bell___Bacterial_spot: Training = 95.56%
# Pepper,_bell___healthy: Training = 97.99%
# Potato___Early_blight: Training = 99.34%
# Potato___Late_blight: Training = 88.31%
# Potato___healthy: Training = 90.48%
# Raspberry___healthy: Training = 100.00%
# Soybean___healthy: Training = 99.71%
# Squash___Powdery_mildew: Training = 100.00%
# Strawberry___Leaf_scorch: Training = 98.07%
# Strawberry___healthy: Training = 99.64%
# Tomato___Bacterial_spot: Training = 98.27%
# Tomato___Early_blight: Training = 61.76%
# Tomato___Late_blight: Training = 90.54%
# Tomato___Leaf_Mold: Training = 85.03%
# Tomato___Septoria_leaf_spot: Training = 90.96%
# Tomato___Spider_mites Two-spotted_spider_mite: Training = 97.53%
# Tomato___Target_Spot: Training = 78.84%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Training = 98.73%
# Tomato___Tomato_mosaic_virus: Training = 98.71%
# Tomato___healthy: Training = 98.11%
#
# 📊 Final Per-Class Validation Accuracy:
#
# Apple___Apple_scab: Validation = 89.93%
# Apple___Black_rot: Validation = 97.56%
# Apple___Cedar_apple_rust: Validation = 98.15%
# Apple___healthy: Validation = 90.38%
# Blueberry___healthy: Validation = 100.00%
# Cherry_(including_sour)___Powdery_mildew: Validation = 96.39%
# Cherry_(including_sour)___healthy: Validation = 98.41%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Validation = 70.00%
# Corn_(maize)___Common_rust_: Validation = 99.64%
# Corn_(maize)___Northern_Leaf_Blight: Validation = 94.76%
# Corn_(maize)___healthy: Validation = 100.00%
# Grape___Black_rot: Validation = 98.80%
# Grape___Esca_(Black_Measles): Validation = 94.02%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Validation = 100.00%
# Grape___healthy: Validation = 98.84%
# Orange___Haunglongbing_(Citrus_greening): Validation = 99.81%
# Peach___Bacterial_spot: Validation = 97.35%
# Peach___healthy: Validation = 92.73%
# Pepper,_bell___Bacterial_spot: Validation = 90.95%
# Pepper,_bell___healthy: Validation = 97.66%
# Potato___Early_blight: Validation = 96.95%
# Potato___Late_blight: Validation = 87.76%
# Potato___healthy: Validation = 75.76%
# Raspberry___healthy: Validation = 100.00%
# Soybean___healthy: Validation = 99.59%
# Squash___Powdery_mildew: Validation = 100.00%
# Strawberry___Leaf_scorch: Validation = 95.09%
# Strawberry___healthy: Validation = 100.00%
# Tomato___Bacterial_spot: Validation = 95.77%
# Tomato___Early_blight: Validation = 53.74%
# Tomato___Late_blight: Validation = 88.17%
# Tomato___Leaf_Mold: Validation = 77.65%
# Tomato___Septoria_leaf_spot: Validation = 87.33%
# Tomato___Spider_mites Two-spotted_spider_mite: Validation = 95.86%
# Tomato___Target_Spot: Validation = 71.70%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Validation = 97.60%
# Tomato___Tomato_mosaic_virus: Validation = 100.00%
# Tomato___healthy: Validation = 97.65%
#
# 📊 Final Per-Class Test Accuracy:
#
# Apple___Apple_scab: Test = 90.98%
# Apple___Black_rot: Test = 97.48%
# Apple___Cedar_apple_rust: Test = 96.23%
# Apple___healthy: Test = 90.42%
# Blueberry___healthy: Test = 99.68%
# Cherry_(including_sour)___Powdery_mildew: Test = 96.30%
# Cherry_(including_sour)___healthy: Test = 98.80%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Test = 80.58%
# Corn_(maize)___Common_rust_: Test = 100.00%
# Corn_(maize)___Northern_Leaf_Blight: Test = 94.42%
# Corn_(maize)___healthy: Test = 100.00%
# Grape___Black_rot: Test = 97.29%
# Grape___Esca_(Black_Measles): Test = 91.89%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Test = 99.50%
# Grape___healthy: Test = 100.00%
# Orange___Haunglongbing_(Citrus_greening): Test = 99.82%
# Peach___Bacterial_spot: Test = 97.91%
# Peach___healthy: Test = 98.65%
# Pepper,_bell___Bacterial_spot: Test = 92.49%
# Pepper,_bell___healthy: Test = 96.83%
# Potato___Early_blight: Test = 98.49%
# Potato___Late_blight: Test = 82.44%
# Potato___healthy: Test = 91.43%
# Raspberry___healthy: Test = 100.00%
# Soybean___healthy: Test = 99.11%
# Squash___Powdery_mildew: Test = 100.00%
# Strawberry___Leaf_scorch: Test = 95.71%
# Strawberry___healthy: Test = 98.91%
# Tomato___Bacterial_spot: Test = 97.92%
# Tomato___Early_blight: Test = 54.60%
# Tomato___Late_blight: Test = 90.30%
# Tomato___Leaf_Mold: Test = 82.81%
# Tomato___Septoria_leaf_spot: Test = 87.77%
# Tomato___Spider_mites Two-spotted_spider_mite: Test = 96.79%
# Tomato___Target_Spot: Test = 76.70%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Test = 97.78%
# Tomato___Tomato_mosaic_virus: Test = 98.51%
# Tomato___healthy: Test = 96.62%

# %%
import numpy as np
import torch
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Initialize lists for storing true labels and predicted probabilities
y_true = []
y_scores = []

# Switch to evaluation mode
model.eval()

# Test Accuracy and collect predictions
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

test_acc = 100 * correct / total
print(f"✅ Test Accuracy: {test_acc:.2f}%")

# Collect true labels and predicted probabilities for PR Curve
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = torch.nn.functional.softmax(outputs, dim=1)
        
        y_true.extend(labels.cpu().numpy())
        y_scores.extend(probs.cpu().numpy())

# Convert lists to numpy arrays for PR curve calculation
y_true = np.array(y_true)
y_scores = np.array(y_scores)

# Plot Precision-Recall curves for each class
plt.figure(figsize=(10, 15))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(y_true == i, y_scores[:, i])
    avg_precision = average_precision_score(y_true == i, y_scores[:, i])
    plt.plot(recall, precision, label=f"{class_names[i]} (AP={avg_precision:.2f})")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve for Plant Disease Classification")
plt.legend()
plt.show()
# Out:
# ✅ Test Accuracy: 95.08%
