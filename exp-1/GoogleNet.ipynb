# %%
# !git clone --depth 1 https://github.com/spMohanty/PlantVillage-Dataset.git
# Out:
# Cloning into 'PlantVillage-Dataset'...
# remote: Enumerating objects: 163214, done.
# remote: Counting objects: 100% (163214/163214), done.
# remote: Compressing objects: 100% (163119/163119), done.
# remote: Total 163214 (delta 93), reused 163211 (delta 93), pack-reused 0 (from 0)
# Receiving objects: 100% (163214/163214), 2.00 GiB | 41.65 MiB/s, done.
# Resolving deltas: 100% (93/93), done.
# Updating files: 100% (182401/182401), done.

# %%
import os

dataset_path = "PlantVillage-Dataset/raw/color"
classes = os.listdir(dataset_path)
print(f"Total classes: {len(classes)}")
print(classes)
# Out:
# Total classes: 38
# ['Tomato___Tomato_mosaic_virus', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Septoria_leaf_spot', 'Corn_(maize)___healthy', 'Potato___healthy', 'Apple___Cedar_apple_rust', 'Potato___Early_blight', 'Pepper,_bell___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Cherry_(including_sour)___healthy', 'Peach___Bacterial_spot', 'Apple___Black_rot', 'Orange___Haunglongbing_(Citrus_greening)', 'Apple___Apple_scab', 'Tomato___Late_blight', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___Common_rust_', 'Strawberry___healthy', 'Tomato___Target_Spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Potato___Late_blight', 'Tomato___Leaf_Mold', 'Squash___Powdery_mildew', 'Grape___Black_rot', 'Cherry_(including_sour)___Powdery_mildew', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Early_blight', 'Peach___healthy', 'Strawberry___Leaf_scorch', 'Blueberry___healthy', 'Grape___Esca_(Black_Measles)', 'Apple___healthy', 'Grape___healthy', 'Soybean___healthy', 'Tomato___Bacterial_spot', 'Raspberry___healthy', 'Tomato___healthy']

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
import os

# Enable CuDNN optimizations
torch.backends.cudnn.benchmark = True

# Define transforms (smaller image size: 128×128)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Reduced image size
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset
dataset_path = "PlantVillage-Dataset/raw/color"  # Modify path in Kaggle
dataset = ImageFolder(root=dataset_path, transform=transform)

# Split dataset: 60% Train, 20% Validation, 20% Test
train_size = int(0.6 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# Use smaller batch size
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# Check dataset class labels
class_names = dataset.classes
print(f"Total classes: {len(class_names)}")
print(class_names)
# Out:
# Total classes: 38
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torchvision.models import GoogLeNet_Weights
from tqdm import tqdm
from torch.utils.data import DataLoader

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load the pretrained GoogleNet model
model = models.googlenet(weights=GoogLeNet_Weights.IMAGENET1K_V1, aux_logits=True)  
num_ftrs = model.fc.in_features  # Get input features of classifier
num_classes = 38  # PlantVillage has 38 classes

# Replace the classifier
model.fc = nn.Linear(num_ftrs, num_classes)  # Main classifier
if model.aux_logits:
    model.aux1.fc2 = nn.Linear(model.aux1.fc2.in_features, num_classes)
    model.aux2.fc2 = nn.Linear(model.aux2.fc2.in_features, num_classes)

# Freeze all layers except classifier
for param in model.parameters():
    param.requires_grad = False

for param in model.fc.parameters():
    param.requires_grad = True
if model.aux_logits:
    for param in model.aux1.fc2.parameters():
        param.requires_grad = True
    for param in model.aux2.fc2.parameters():
        param.requires_grad = True

# Move model to device
model = model.to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.0001)

# Mixed Precision Training
scaler = torch.amp.GradScaler()

# DataLoader (GoogleNet expects 224x224 images)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# Training setup
num_epochs = 10
train_acc_history = []
val_acc_history = []
test_acc_history = []

for epoch in range(num_epochs):
    model.train()
    correct = 0
    total = 0
    running_loss = 0.0

    loop = tqdm(train_loader, leave=True, desc=f"Epoch {epoch+1}/{num_epochs}")
    for images, labels in loop:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type="cuda"):
            outputs, aux1, aux2 = model(images) if model.aux_logits else (model(images), None, None)
            loss = criterion(outputs, labels)

            # Auxiliary loss
            if aux1 is not None and aux2 is not None:
                loss += 0.3 * criterion(aux1, labels) + 0.3 * criterion(aux2, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

        loop.set_postfix(loss=f"{running_loss / len(train_loader):.4f}", acc=f"{100 * correct / total:.2f}%")

# Save model
torch.save(model.state_dict(), "googlenet_trained.pth")
print("\n🚀 Model saved as googlenet_trained.pth")
# Out:
# Using device: cuda
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 149MB/s]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/googlenet.py:341: UserWarning: auxiliary heads in the pretrained googlenet model are NOT pretrained, so make sure to train them
#   warnings.warn(
# Epoch 1/10: 100%|██████████| 1019/1019 [00:55<00:00, 18.37it/s, acc=47.48%, loss=3.9348]
# Epoch 2/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.60it/s, acc=77.81%, loss=2.3382]
# Epoch 3/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.38it/s, acc=84.54%, loss=1.7277]
# Epoch 4/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.51it/s, acc=86.85%, loss=1.4173]
# Epoch 5/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.42it/s, acc=88.42%, loss=1.2255]
# Epoch 6/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.35it/s, acc=89.27%, loss=1.0965]
# Epoch 7/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.39it/s, acc=90.06%, loss=1.0116]
# Epoch 8/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.29it/s, acc=90.48%, loss=0.9460]
# Epoch 9/10: 100%|██████████| 1019/1019 [00:47<00:00, 21.36it/s, acc=91.08%, loss=0.8898]
# Epoch 10/10: 100%|██████████| 1019/1019 [00:50<00:00, 20.27it/s, acc=91.46%, loss=0.8503]
# 🚀 Model saved as googlenet_trained.pth

# %%
import numpy as np
import torch

# Function to calculate per-class accuracy for different datasets
def calculate_per_class_accuracy(model, data_loaders, device, datasets=["Training", "Validation", "Test"]):
    for dataset_type, data_loader in zip(datasets, data_loaders):
        model.eval()
        class_correct = np.zeros(num_classes)
        class_total = np.zeros(num_classes)

        with torch.no_grad():
            for images, labels in data_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs, 1)

                for i in range(len(labels)):
                    label = labels[i].item()
                    class_correct[label] += (predicted[i] == label).item()
                    class_total[label] += 1

        # Print per-class accuracy for the current dataset
        print(f"\n📊 Final Per-Class {dataset_type} Accuracy:\n")
        for i in range(num_classes):
            accuracy = 100 * class_correct[i] / class_total[i] if class_total[i] > 0 else 0
            print(f"{class_names[i]}: {dataset_type} = {accuracy:.2f}%")


# ---------- Calculate Per-Class Accuracy for Training, Validation, and Test Data ----------
# List of data loaders for training, validation, and test datasets
data_loaders = [train_loader, val_loader, test_loader]

# List of dataset names
datasets = ["Training", "Validation", "Test"]

# Call the function for calculating accuracy
calculate_per_class_accuracy(model, data_loaders, device, datasets=datasets)
# Out:
# 📊 Final Per-Class Training Accuracy:
#
# Apple___Apple_scab: Training = 85.94%
# Apple___Black_rot: Training = 96.52%
# Apple___Cedar_apple_rust: Training = 93.53%
# Apple___healthy: Training = 93.78%
# Blueberry___healthy: Training = 99.30%
# Cherry_(including_sour)___Powdery_mildew: Training = 97.82%
# Cherry_(including_sour)___healthy: Training = 96.35%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Training = 74.32%
# Corn_(maize)___Common_rust_: Training = 99.86%
# Corn_(maize)___Northern_Leaf_Blight: Training = 93.00%
# Corn_(maize)___healthy: Training = 100.00%
# Grape___Black_rot: Training = 91.70%
# Grape___Esca_(Black_Measles): Training = 94.52%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Training = 99.19%
# Grape___healthy: Training = 97.02%
# Orange___Haunglongbing_(Citrus_greening): Training = 99.78%
# Peach___Bacterial_spot: Training = 97.02%
# Peach___healthy: Training = 97.31%
# Pepper,_bell___Bacterial_spot: Training = 91.12%
# Pepper,_bell___healthy: Training = 96.02%
# Potato___Early_blight: Training = 97.46%
# Potato___Late_blight: Training = 88.49%
# Potato___healthy: Training = 61.86%
# Raspberry___healthy: Training = 97.17%
# Soybean___healthy: Training = 98.97%
# Squash___Powdery_mildew: Training = 99.56%
# Strawberry___Leaf_scorch: Training = 98.35%
# Strawberry___healthy: Training = 99.24%
# Tomato___Bacterial_spot: Training = 94.58%
# Tomato___Early_blight: Training = 61.01%
# Tomato___Late_blight: Training = 83.51%
# Tomato___Leaf_Mold: Training = 82.26%
# Tomato___Septoria_leaf_spot: Training = 74.50%
# Tomato___Spider_mites Two-spotted_spider_mite: Training = 84.75%
# Tomato___Target_Spot: Training = 84.96%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Training = 97.35%
# Tomato___Tomato_mosaic_virus: Training = 73.36%
# Tomato___healthy: Training = 97.43%
#
# 📊 Final Per-Class Validation Accuracy:
#
# Apple___Apple_scab: Validation = 82.44%
# Apple___Black_rot: Validation = 95.65%
# Apple___Cedar_apple_rust: Validation = 84.48%
# Apple___healthy: Validation = 94.41%
# Blueberry___healthy: Validation = 98.10%
# Cherry_(including_sour)___Powdery_mildew: Validation = 98.53%
# Cherry_(including_sour)___healthy: Validation = 94.84%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Validation = 71.79%
# Corn_(maize)___Common_rust_: Validation = 99.58%
# Corn_(maize)___Northern_Leaf_Blight: Validation = 85.56%
# Corn_(maize)___healthy: Validation = 99.60%
# Grape___Black_rot: Validation = 88.80%
# Grape___Esca_(Black_Measles): Validation = 96.17%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Validation = 99.08%
# Grape___healthy: Validation = 98.89%
# Orange___Haunglongbing_(Citrus_greening): Validation = 99.37%
# Peach___Bacterial_spot: Validation = 96.40%
# Peach___healthy: Validation = 98.41%
# Pepper,_bell___Bacterial_spot: Validation = 88.57%
# Pepper,_bell___healthy: Validation = 95.87%
# Potato___Early_blight: Validation = 95.31%
# Potato___Late_blight: Validation = 89.47%
# Potato___healthy: Validation = 75.86%
# Raspberry___healthy: Validation = 98.72%
# Soybean___healthy: Validation = 99.29%
# Squash___Powdery_mildew: Validation = 98.92%
# Strawberry___Leaf_scorch: Validation = 96.76%
# Strawberry___healthy: Validation = 100.00%
# Tomato___Bacterial_spot: Validation = 94.16%
# Tomato___Early_blight: Validation = 54.50%
# Tomato___Late_blight: Validation = 84.55%
# Tomato___Leaf_Mold: Validation = 76.14%
# Tomato___Septoria_leaf_spot: Validation = 72.34%
# Tomato___Spider_mites Two-spotted_spider_mite: Validation = 83.82%
# Tomato___Target_Spot: Validation = 80.97%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Validation = 96.16%
# Tomato___Tomato_mosaic_virus: Validation = 63.75%
# Tomato___healthy: Validation = 95.51%
#
# 📊 Final Per-Class Test Accuracy:
#
# Apple___Apple_scab: Test = 81.97%
# Apple___Black_rot: Test = 96.97%
# Apple___Cedar_apple_rust: Test = 91.49%
# Apple___healthy: Test = 95.38%
# Blueberry___healthy: Test = 99.07%
# Cherry_(including_sour)___Powdery_mildew: Test = 97.56%
# Cherry_(including_sour)___healthy: Test = 97.75%
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: Test = 76.00%
# Corn_(maize)___Common_rust_: Test = 98.74%
# Corn_(maize)___Northern_Leaf_Blight: Test = 87.32%
# Corn_(maize)___healthy: Test = 99.54%
# Grape___Black_rot: Test = 92.46%
# Grape___Esca_(Black_Measles): Test = 94.48%
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): Test = 99.17%
# Grape___healthy: Test = 97.96%
# Orange___Haunglongbing_(Citrus_greening): Test = 99.74%
# Peach___Bacterial_spot: Test = 96.18%
# Peach___healthy: Test = 94.59%
# Pepper,_bell___Bacterial_spot: Test = 88.95%
# Pepper,_bell___healthy: Test = 94.16%
# Potato___Early_blight: Test = 93.37%
# Potato___Late_blight: Test = 86.14%
# Potato___healthy: Test = 42.31%
# Raspberry___healthy: Test = 93.83%
# Soybean___healthy: Test = 98.99%
# Squash___Powdery_mildew: Test = 99.39%
# Strawberry___Leaf_scorch: Test = 98.23%
# Strawberry___healthy: Test = 96.91%
# Tomato___Bacterial_spot: Test = 94.83%
# Tomato___Early_blight: Test = 57.87%
# Tomato___Late_blight: Test = 81.03%
# Tomato___Leaf_Mold: Test = 76.62%
# Tomato___Septoria_leaf_spot: Test = 75.29%
# Tomato___Spider_mites Two-spotted_spider_mite: Test = 79.58%
# Tomato___Target_Spot: Test = 80.68%
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: Test = 97.61%
# Tomato___Tomato_mosaic_virus: Test = 60.76%
# Tomato___healthy: Test = 95.37%

# %%
import numpy as np
import torch
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Initialize lists for storing true labels and predicted probabilities
y_true = []
y_scores = []

# Switch to evaluation mode
model.eval()

# Test Accuracy and collect predictions
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

test_acc = 100 * correct / total
print(f"✅ Test Accuracy: {test_acc:.2f}%")

# Collect true labels and predicted probabilities for PR Curve
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = torch.nn.functional.softmax(outputs, dim=1)
        
        y_true.extend(labels.cpu().numpy())
        y_scores.extend(probs.cpu().numpy())

# Convert lists to numpy arrays for PR curve calculation
y_true = np.array(y_true)
y_scores = np.array(y_scores)

# Plot Precision-Recall curves for each class
plt.figure(figsize=(10, 15))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(y_true == i, y_scores[:, i])
    avg_precision = average_precision_score(y_true == i, y_scores[:, i])
    plt.plot(recall, precision, label=f"{class_names[i]} (AP={avg_precision:.2f})")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve for Plant Disease Classification")
plt.legend()
plt.show()
# Out:
# ✅ Test Accuracy: 92.66%
